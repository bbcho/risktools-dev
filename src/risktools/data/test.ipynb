# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd 
import numpy as np
import risktools as rt

# %%
rt.data.open_data('usSwapCurves')['table']
# Out:
#           date  zeroRates
# 0   2023-01-04     0.0445
# 1   2023-02-02     0.0443
# 2   2023-03-03     0.0453
# 3   2023-04-03     0.0460
# 4   2023-05-05     0.0466
# ..         ...        ...
# 361 2052-08-15     0.0329
# 362 2052-09-13     0.0329
# 363 2052-10-14     0.0329
# 364 2052-11-12     0.0329
# 365 2052-12-11     0.0329
#
# [366 rows x 2 columns]

# %%
rt.data.open_data('futuresRef')
# Out:
# /home/bcho/PROJECTS/risktools-dev/src/risktools/data/__init__.py:114: UserWarning: File actions for futuresRef not defined. Running default behavior.
#   _warnings.warn(f"File actions for {nm} not defined. Running default behavior.")
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# File ~/PROJECTS/risktools-dev/src/risktools/data/__init__.py:112, in open_data(nm)
#     111 try:
# --> 112     df = _file_actions[nm]["load_func"](fp)
#     113 except:
#
# File ~/PROJECTS/risktools-dev/src/risktools/data/__init__.py:188, in _load_data(fn)
#     187     if isinstance(dd[key], _pd.DataFrame) == True:
# --> 188         df = _try_dates(df)
#     190 return dd
#
# UnboundLocalError: local variable 'df' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# ...
