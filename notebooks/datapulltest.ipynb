# %%
# %load_ext autoreload
# %autoreload 2
import risktools as rt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
rt.data.open_data('crudeOil')['xomAssays']
# Out:
#          assay                  terengganu Whole_crude  \
# 0   terengganu               Cut volume, %       100.0
# 1   terengganu                API Gravity,      73.097
# 2   terengganu  Specific Gravity (60/60F),      0.6916
# 3   terengganu                Carbon, wt %     84.7183
# 4   terengganu              Hydrogen, wt %     15.2042
# ..         ...                         ...         ...
# 41       kearl                         NaN     10.3461
# 42       kearl                         NaN      3.9013
# 43       kearl                         NaN         NaN
# 44       kearl                         NaN         NaN
# 45       kearl                         NaN         NaN
#
#     Butane_and_Lighter_IBP_60F  Lt_Naphtha_C5_165F  Hvy_Naphtha_165_330F  \
# 0                       1.1575             57.1544               33.0106
# 1                     115.4596             86.5408               57.2095
# 2                       0.5730              0.6490                0.7498
# ...

# %%
rt.data.get_names()
# Out:
# ['crudeOil',
#  'cushing',
#  'dflong',
#  'dfwide',
#  'eiaStocks',
#  'eiaStorageCap',
#  'eurodollar',
#  'expiry_table',
#  'fizdiffs',
#  'futuresRef',
#  'fxfwd',
#  'holidaysOil',
#  'ohlc',
#  'planets',
#  'refineryLPdata',
#  'tickers_eia',
#  'tradeCycle',
#  'tradeHubs',
#  'tradeprocess',
#  'wti_swap',
#  'stocks',
#  'tsQuotes',
#  'usSwapCurves',
#  'usSwapCurvesPar']

# %%
rt.data.open_data('cushing')
# Out:
# {'c1':            date   Open   High    Low  Close
#  0    2013-01-02  91.78  93.87  91.56  93.12
#  1    2013-01-03  92.91  93.30  92.49  92.92
#  2    2013-01-04  92.86  93.21  91.52  93.09
#  3    2013-01-07  93.21  93.35  92.42  93.19
#  4    2013-01-08  93.32  93.80  92.67  93.15
#  ...         ...    ...    ...    ...    ...
#  2669 2023-08-14  83.09  83.20  81.76  82.51
#  2670 2023-08-15  82.52  82.91  80.40  80.99
#  2671 2023-08-16  81.23  81.43  79.05  79.38
#  2672 2023-08-17  79.25  81.08  78.95  80.39
#  2673 2023-08-18  80.04  81.61  79.59  81.25
#
#  [2674 rows x 5 columns],
#  'c2':            date     Open     High      Low  Close
#  0    2013-01-02  92.2038  94.3035  91.9828  93.55
#  1    2013-01-03  93.3300  93.7217  92.9081  93.34
#  2    2013-01-04  93.2790  93.6305  91.9329  93.51
#  3    2013-01-07  93.6501  93.7908  92.8564  93.63
#  4    2013-01-08  93.7708  94.2531  93.1177  93.60
#  ...         ...      ...      ...      ...    ...
# ...

# %%
rt.data.open_data('dfwide')
# Out:
#              CL01   CL02   CL03   CL04   CL05   CL06   CL07   CL08   CL09  \
# date
# 2007-01-02  61.05  62.38  63.26  63.95  64.54  65.04  65.49  65.89  66.23
# 2007-01-03  58.32  59.41  60.34  61.05  61.65  62.18  62.64  63.06  63.41
# 2007-01-04  55.59  56.64  57.60  58.38  59.04  59.62  60.12  60.58  60.98
# 2007-01-05  56.31  57.39  58.35  59.18  59.91  60.54  61.08  61.56  61.98
# 2007-01-08  56.09  57.36  58.38  59.26  60.01  60.67  61.24  61.76  62.21
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2023-10-16  86.66  85.26  84.02  82.92  82.04  81.32  80.71  80.15  79.63
# 2023-10-17  86.66  85.44  84.30  83.26  82.42  81.71  81.08  80.51  79.97
# 2023-10-18  88.32  87.27  86.09  84.97  84.03  83.23  82.53  81.89  81.29
# 2023-10-19  89.37  88.37  87.06  85.79  84.69  83.77  82.98  82.27  81.60
# 2023-10-20    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# ...
